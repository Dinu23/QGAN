# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gen_loss = -np.load("simulate4x4\gen_loss_final.npy")
disc_loss = -np.load("simulate4x4\disc_loss_final.npy")[:,0]
plt.plot(gen_loss,label="Generator loss")
plt.plot(disc_loss, label="Discriminator loss")
plt.legend()
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')

# %%
gen_loss = -np.load("state_vector4x4\gen_loss_final.npy")
disc_loss = -np.load("state_vector4x4\disc_loss_final.npy")[:,0]
plt.plot(gen_loss,label="Generator loss")
plt.plot(disc_loss, label="Discriminator loss")
plt.legend()
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')

# %%
gen_loss = np.load("simulate8x8\gen_loss_final_1.npy")
disc_loss = -np.load("simulate8x8\disc_loss_final_1.npy")[:,0]
plt.plot(gen_loss,label="Generator loss")
plt.plot(disc_loss, label="Discriminator loss")
plt.legend()
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')

# %%
gen_loss = np.load("state_vector8x8\gen_loss_final_1.npy")
disc_loss = -np.load("state_vector8x8\disc_loss_final_1.npy")[:,0]
plt.plot(gen_loss,label="Generator loss")
plt.plot(disc_loss, label="Discriminator loss")
plt.legend()
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')
